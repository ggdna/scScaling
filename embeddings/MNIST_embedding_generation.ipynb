# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision import datasets, transforms
import pandas as pd
import os

# %%
# mnist loader :)
transform = transforms.Compose([transforms.ToTensor()])
data = datasets.MNIST(root="./data", train=True, download=True, transform=transform)
train_size = int(0.5 * len(data))
val_size = len(data) - train_size
train_data, val_data = random_split(data, [train_size, val_size])
train_loader = DataLoader(train_data, batch_size=64, shuffle=True)
val_loader = DataLoader(val_data, batch_size=64, shuffle=False)

# save validation samples and labels :D
os.makedirs("MNIST", exist_ok=True)
val_samples = [(img.numpy().squeeze(), label) for img, label in val_data]
val_df = pd.DataFrame(val_samples, columns=["image", "label"])
val_df.to_csv("MNIST/held_out.csv", index=False)

# vanilla autoencoder model :D
class Autoencoder(nn.Module):
    def __init__(self):
        super().__init__()
        self.encoder = nn.Sequential(
            nn.Linear(28 * 28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU(),
            nn.Linear(64, 8)  # bottleneck layer
        )
        self.decoder = nn.Sequential(
            nn.Linear(8, 64),
            nn.ReLU(),
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 28 * 28),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = x.view(x.size(0), -1)  # flatten
        x = self.encoder(x)
        x = self.decoder(x)
        x = x.view(x.size(0), 1, 28, 28)  # reshape to image
        return x
    
# early stopping helper!
class EarlyStopping:
    def __init__(self, patience=5):
        self.patience = patience
        self.counter = 0
        self.best_loss = None
        self.early_stop = False

    def __call__(self, val_loss):
        if self.best_loss is None or val_loss < self.best_loss:
            self.best_loss = val_loss
            self.counter = 0
        else:
            self.counter += 1
            if self.counter >= self.patience:
                self.early_stop = True

# %%
# training and validation loop :)
model = Autoencoder()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-4)

# early stopping setup
early_stopping = EarlyStopping(patience=5)

for epoch in range(50):
    # training
    model.train()
    train_loss = 0.0
    for imgs, _ in train_loader:
        optimizer.zero_grad()
        outputs = model(imgs)
        loss = criterion(outputs, imgs)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()

    train_loss /= len(train_loader)

    # validation
    model.eval()
    val_loss = 0.0
    embeddings = []
    with torch.no_grad():
        for imgs, labels in val_loader:
            outputs = model(imgs)
            loss = criterion(outputs, imgs)
            val_loss += loss.item()

            # save embeddings
            encoded_imgs = model.encoder(imgs.view(imgs.size(0), -1)).cpu().numpy()
            for emb, label in zip(encoded_imgs, labels.numpy()):
                embeddings.append((label, *emb))

    val_loss /= len(val_loader)

    # save embeddings to file
    embeddings_df = pd.DataFrame(embeddings)
    embeddings_df.to_csv(f"MNIST/AE_epoch{epoch + 1}.csv", index=False, header=False)

    print(f"epoch {epoch + 1}, train loss: {train_loss:.4f}, val loss: {val_loss:.4f}")

    # early stopping check
    early_stopping(val_loss)
    if early_stopping.early_stop:
        print("early stopping triggered! :)")
        break

print("training done! 🎉")
# Out:
# epoch 1, train loss: 0.0998, val loss: 0.0681
# epoch 2, train loss: 0.0652, val loss: 0.0625
# epoch 3, train loss: 0.0604, val loss: 0.0583
# epoch 4, train loss: 0.0549, val loss: 0.0527
# epoch 5, train loss: 0.0503, val loss: 0.0473
# epoch 6, train loss: 0.0434, val loss: 0.0414
# epoch 7, train loss: 0.0401, val loss: 0.0389
# epoch 8, train loss: 0.0377, val loss: 0.0367
# epoch 9, train loss: 0.0359, val loss: 0.0353
# epoch 10, train loss: 0.0346, val loss: 0.0341
# epoch 11, train loss: 0.0333, val loss: 0.0328
# epoch 12, train loss: 0.0322, val loss: 0.0319
# epoch 13, train loss: 0.0315, val loss: 0.0313
# epoch 14, train loss: 0.0309, val loss: 0.0308
# epoch 15, train loss: 0.0305, val loss: 0.0304
# epoch 16, train loss: 0.0300, val loss: 0.0300
# epoch 17, train loss: 0.0296, val loss: 0.0296
# epoch 18, train loss: 0.0292, val loss: 0.0292
# epoch 19, train loss: 0.0288, val loss: 0.0288
# epoch 20, train loss: 0.0284, val loss: 0.0284
# epoch 21, train loss: 0.0280, val loss: 0.0280
# epoch 22, train loss: 0.0275, val loss: 0.0275
# epoch 23, train loss: 0.0271, val loss: 0.0272
# epoch 24, train loss: 0.0268, val loss: 0.0270
# epoch 25, train loss: 0.0266, val loss: 0.0267
# epoch 26, train loss: 0.0263, val loss: 0.0265
# epoch 27, train loss: 0.0261, val loss: 0.0263
# epoch 28, train loss: 0.0260, val loss: 0.0262
# epoch 29, train loss: 0.0258, val loss: 0.0260
# epoch 30, train loss: 0.0256, val loss: 0.0258
# epoch 31, train loss: 0.0254, val loss: 0.0257
# epoch 32, train loss: 0.0253, val loss: 0.0255
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /media/gokul/VGX1000 SSD/scScaling/embeddings/MNIST_embedding_generation.ipynb Cell 3 line 3
#      <a href='vscode-notebook-cell:/media/gokul/VGX1000%20SSD/scScaling/embeddings/MNIST_embedding_generation.ipynb#W2sZmlsZQ%3D%3D?line=27'>28</a> for imgs, labels in val_loader:
#      <a href='vscode-notebook-cell:/media/gokul/VGX1000%20SSD/scScaling/embeddings/MNIST_embedding_generation.ipynb#W2sZmlsZQ%3D%3D?line=28'>29</a>     outputs = model(imgs)
# ---> <a href='vscode-notebook-cell:/media/gokul/VGX1000%20SSD/scScaling/embeddings/MNIST_embedding_generation.ipynb#W2sZmlsZQ%3D%3D?line=29'>30</a>     loss = criterion(outputs, imgs)
#      <a href='vscode-notebook-cell:/media/gokul/VGX1000%20SSD/scScaling/embeddings/MNIST_embedding_generation.ipynb#W2sZmlsZQ%3D%3D?line=30'>31</a>     val_loss += loss.item()
#      <a href='vscode-notebook-cell:/media/gokul/VGX1000%20SSD/scScaling/embeddings/MNIST_embedding_generation.ipynb#W2sZmlsZQ%3D%3D?line=32'>33</a>     # save embeddings
#
# File /usr/lib/python3/dist-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/lib/python3/dist-packages/torch/nn/modules/loss.py:536, in MSELoss.forward(self, input, target)
#     535 def forward(self, input: Tensor, target: Tensor) -> Tensor:
# --> 536     return F.mse_loss(input, target, reduction=self.reduction)
#
# File /usr/lib/python3/dist-packages/torch/nn/functional.py:3295, in mse_loss(input, target, size_average, reduce, reduction)
#    3292     reduction = _Reduction.legacy_get_string(size_average, reduce)
#    3294 expanded_input, expanded_target = torch.broadcast_tensors(input, target)
# -> 3295 return torch._C._nn.mse_loss(expanded_input, expanded_target, _Reduction.get_enum(reduction))
#
# KeyboardInterrupt:
